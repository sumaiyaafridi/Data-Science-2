# %%
import pandas as pd

# %%
df=pd.read_excel('./Datasets/datac.xlsx')

# %%
df
# Out:
#      Name       Date  Marks  Experience  Qualification
# 0  Nabeel 2020-12-01    NaN         3.0            2.0
# 1     Ali 2020-12-02  450.0         4.0            1.0
# 2   Ahmad 2020-12-03  350.0         5.0            NaN
# 3   Maria        NaT  300.0         2.0            2.0
# 4   Aamir 2020-12-05  489.0         NaN            1.0

# %%
df=df.fillna(df.median())
# Out:
# <ipython-input-64-42d29455c84b>:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   df=df.fillna(df.median())

# %%
df
# Out:
#      Name       Date  Marks  Experience  Qualification
# 0  Nabeel 2020-12-01  400.0         3.0            2.0
# 1     Ali 2020-12-02  450.0         4.0            1.0
# 2   Ahmad 2020-12-03  350.0         5.0            1.5
# 3   Maria        NaT  300.0         2.0            2.0
# 4   Aamir 2020-12-05  489.0         3.5            1.0

# %%
df=df.fillna(df.mode())

# %%
df
# Out:
#      Name       Date  Marks  Experience  Qualification
# 0  Nabeel 2020-12-01  400.0         3.0            2.0
# 1     Ali 2020-12-02  450.0         4.0            1.0
# 2   Ahmad 2020-12-03  350.0         5.0            1.5
# 3   Maria 2020-12-05  300.0         2.0            2.0
# 4   Aamir 2020-12-05  489.0         3.5            1.0

# %% [markdown]
# ## for plotting use this library

# %%
import matplotlib.pyplot as plt

# %%
x=df['Name']

# %%
y=df['Experience']

# %%
plt.plot(x,y)

# %%
x=df['Name']
y=df['Marks']

# %%
plt.plot(x,y, '*')

# %%
plt.plot(x,y, '>')

# %%
plt.plot(y, '*')

# %%
plt.plot(x,y, marker='*')

# %%
plt.plot(x,y, marker='<')

# %% [markdown]
# ## format string marker-line-color below 'r' is color

# %% [markdown]
# ## marker size=ms

# %%
plt.plot(x,y, 'o:g', ms=20)

# %% [markdown]
# ## mec= is marker edge color

# %%
plt.plot(y, marker = 'o', ms = 20, mec = 'r')
plt.show()

# %%
plt.plot(y, marker = 'o', ms = 20, mfc = 'r')
plt.show()

# %%
plt.plot(x,y, linestyle='dashed')

# %%
plt.plot(x,y)

plt.title("Candidates for job")

plt.xlabel("Name of candidates")
plt.ylabel("Marks of candidates")
# Out:
# Text(0, 0.5, 'Marks of candidates')

# %%
plt.plot(x,y)

plt.title("Candidates for job")

plt.xlabel("Name")
plt.ylabel("Experience")
plt.grid()

# %%
plt.plot(x,y)

plt.title("Candidates for job")

plt.xlabel("Name")
plt.ylabel("Experience")
plt.grid(axis='y', linestyle='--')

# %%
y1=df['Experience']
y1
# Out:
# 0    3.0
# 1    4.0
# 2    5.0
# 3    2.0
# 4    3.5
# Name: Experience, dtype: float64

# %%
plt.subplot(1,2,1)
plt.plot(x,y)

plt.subplot(1,2,2)
plt.plot(x,y1)

# %%
plt.subplot(2,2,1) #2 row 2 columns 1 plot
plt.plot(x,y)

plt.subplot(2,2,2)
plt.plot(x,y1)


plt.subplot(2,2,3)
plt.plot(x,y)

plt.subplot(2,2,4)
plt.plot(x,y1)
