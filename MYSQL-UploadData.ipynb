# %%
import mysql.connector

# %%
db=mysql.connector.connect(
   host="localhost",
   user="sumayyah",
   password="afridi24.",
   database="Star"
)

# %%
db

# %%
c=db.cursor()

# %%
c

# %% [markdown]
# ### SHOW

# %%
c.execute("SHOW DATABASES")

# %%
c

# %%
for x in c:
    print(x)
# Out:
# ('Cafe',)
# ('MIS',)
# ('School',)
# ('Star',)
# ('information_schema',)
# ('mysql',)
# ('performance_schema',)
# ('sys',)

# %%
c.execute("SHOW TABLES")

# %%
for x in c:
    print(x)
# Out:
# ('Census',)
# ('Flights',)
# ('Registeration',)
# ('Users',)
# ('resturants',)

# %% [markdown]
# ### 1st Step

# %%
c.execute("CREATE TABLE data (Country VARCHAR(255), State VARCHAR(255), Salary INT(255), IlliteracyRate INT(255))")

# %%
c.execute("SHOW TABLES")
for i in c:
    print(i)
# Out:
# ('Census',)
# ('Flights',)
# ('Registeration',)
# ('Users',)
# ('data',)
# ('resturants',)

# %% [markdown]
# ### 2nd Step

# %%
import csv
import pandas as pd

df = pd.read_excel("./Datasets/rest.xlsx") # Replace Excel_file_name with your excel sheet name

# %%
df
# Out:
#                          name price_level  rating              city
# 0        Little Caesars Pizza           1     3.8          Live Oak
# 1             Texas Roadhouse           2     4.5          Valdosta
# 2                    Fazoli's           1     4.4          Valdosta
# 3                      SUBWAY           1     2.8          Valdosta
# 4                 Red Lobster           2     4.1          Valdosta
# ..                        ...         ...     ...               ...
# 887        Buffalo Wild Wings           2     3.5          Torrance
# 888         Brix Sunset Beach           2     4.4  Huntington Beach
# 889  Lucille’s Smokehouse BBQ           2     4.5        Long Beach
# 890  Agaves kitchen | tequila           2     4.1        Long Beach
# 891               Spaghettini           3     4.6        Seal Beach
#
# [892 rows x 4 columns]

# %% [markdown]
# ### 3rd Step

# %%
 for i,row in df.iterrows():
            sql = "INSERT INTO Star.resturants VALUES (%s,%s,%s,%s)"
            c.execute(sql, tuple(row))
            db.commit()
            print("Record inserted")
# Out:
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# ...

# %%
for i in c:
    print(i)

# %%
c.execute("SELECT * FROM resturants")

# %%
myresult = c.fetchall()
for x in myresult:
  print(x)
# Out:
# ('Little Caesars Pizza', '1', 4, 'Live Oak')
# ('Texas Roadhouse', '2', 5, 'Valdosta')
# ("Fazoli's", '1', 4, 'Valdosta')
# ('SUBWAY', '1', 3, 'Valdosta')
# ('Red Lobster', '2', 4, 'Valdosta')
# ('SUBWAY', '1', 4, 'Valdosta')
# ('Pizza Hut', '1', 3, 'Valdosta')
# ('SUBWAY', '1', 3, 'Valdosta')
# ('Austins Cattle Co', '2', 4, 'Valdosta')
# ("Cheddar's Scratch Kitchen", '2', 4, 'Valdosta')
# ('Pilot Travel Center', '-1', 4, 'Valdosta')
# ('Subway', '1', 4, 'Live Oak')
# ('Subway', '1', 3, 'Jasper')
# ('Subway', '1', 4, 'Madison')
# ('SUBWAY', '1', 3, 'Lake Park')
# ('Mandarin Express', '1', 4, 'Valdosta')
# ("Jimmy John's", '1', 4, 'Valdosta')
# ('Chick-fil-A', '1', 4, 'Valdosta')
# ('Pretzelmaker', '1', 3, 'Valdosta')
# ('SUBWAY', '1', 1, 'Valdosta')
# ("Wendy's", '1', 4, 'Valdosta')
# ('SUBWAY® Restaurants', '1', 3, 'Valdosta')
# ('SUBWAY', '1', 4, 'Valdosta')
# ('Subway', '1', 4, 'Madison')
# ('Pizza Hut', '1', 4, 'Live Oak')
# ('Sonic Drive-In', '1', 3, 'Valdosta')
# ...
