# %%
import pandas as pd

df=pd.read_excel(r's1.xlsx');

df=pd.DataFrame(df)

df.head(1) #will print first 1 row
df.tail(1) #will print last rows
# Out:
#       ALTCODE        NAME DEGREE_CODE       SEM_CODE  \
# 2272    16417  Rooh Ullah      BS(SE)  CSD-SPRING-21
#
#                           NAME2  CRHRS  MARKS  POINTS       EMP_ID  \
# 2272  HUMAN RESOURCE MANAGEMENT      3    NaN     NaN  104-17-1055
#
#                  NAME3 SEMESTER  SECCORSCODE SEX INACTIVE
# 2272  Muhammad Shakeel   INU-19    102102098   M        N

# %%
df.columns
# Out:
# Index(['ALTCODE', 'NAME', 'DEGREE_CODE', 'SEM_CODE', 'NAME2', 'CRHRS', 'MARKS',
#        'POINTS', 'EMP_ID', 'NAME3', 'SEMESTER', 'SECCORSCODE', 'SEX',
#        'INACTIVE'],
#       dtype='object')

# %%
df[10:14]  #slicing of rows
# Out:
#     ALTCODE           NAME DEGREE_CODE       SEM_CODE  \
# 10    15554  Farhan Akhtar      BS(SE)  CSD-SPRING-19
# 11    15554  Farhan Akhtar      BS(SE)  CSD-SPRING-19
# 12    15531   Shahid Nasir      BS(SE)  CSD-SPRING-19
# 13    15531   Shahid Nasir      BS(SE)  CSD-SPRING-19
#
#                              NAME2  CRHRS  MARKS  POINTS       EMP_ID  \
# 10     ISLAMIC STUDIES/PAK STUDIES      3   60.0     2.0  104-16-1038
# 11  ENGLISH-I (FUNCTIONAL ENGLISH)      3   89.0     4.0  104-18-1012
# 12  COMPUTING FUNDAMENTALS(THEORY)      2   68.0     2.5  718-05-1002
# 13    COMPUTING FUNDAMENTALS (LAB)      1   88.0     4.0  718-05-1002
#
#                     NAME3 SEMESTER  SECCORSCODE SEX INACTIVE
# 10          Beenish Shuja   INU-18    101902086   M        N
# 11  Naeem Ullah KaKa Khel   INU-18    101902087   M        N
# 12       Dr. Atif Ishtiaq   INU-18    101902081   M        N
# 13       Dr. Atif Ishtiaq   INU-18    101902082   M        N

# %%
 df.iloc[:, 2:5]  #slicing of columns here iloc is index location
# Out:
#      DEGREE_CODE       SEM_CODE                                    NAME2
# 0         BS(SE)  CSD-SPRING-20               HUMAN COMPUTER INTERACTION
# 1         BS(SE)  CSD-SPRING-20     INFORMATION SYSTEM & DATA PROCESSING
# 2         BS(SE)  CSD-SPRING-20           SOFTWARE DESIGN & ARCHITECTURE
# 3         BS(SE)  CSD-SPRING-20  ENGLISH -III (TECHNICAL REPORT WRITING)
# 4         BS(SE)  CSD-SPRING-20       SOFTWARE VERIFICATION & VALIDATION
# ...          ...            ...                                      ...
# 2268      BS(SE)  CSD-SPRING-21      DATA STRUCTURES & ALGORITHM(THEORY)
# 2269      BS(SE)  CSD-SPRING-21         DATA STRUCTURES & ALGORITHM(LAB)
# 2270      BS(SE)  CSD-SPRING-21                     SOFTWARE ENGINEERING
# 2271      BS(SE)  CSD-SPRING-21                   DIFFERENTIAL EQUATIONS
# 2272      BS(SE)  CSD-SPRING-21                HUMAN RESOURCE MANAGEMENT
#
# [2273 rows x 3 columns]

# %%
s = df['MARKS'] / 5    #df['MARKS']    #df['ID']
s.head()
# Out:
# 0    14.8
# 1    16.8
# 2    16.8
# 3    16.0
# 4    14.6
# Name: MARKS, dtype: float64

# %%
df_agr = df.groupby(['ALTCODE'])
df_agr.head()
# Out:
#       ALTCODE               NAME DEGREE_CODE       SEM_CODE  \
# 0       16550  Muhammad Ali Khan      BS(SE)  CSD-SPRING-20
# 1       16550  Muhammad Ali Khan      BS(SE)  CSD-SPRING-20
# 2       16550  Muhammad Ali Khan      BS(SE)  CSD-SPRING-20
# 3       16550  Muhammad Ali Khan      BS(SE)  CSD-SPRING-20
# 4       16550  Muhammad Ali Khan      BS(SE)  CSD-SPRING-20
# ...       ...                ...         ...            ...
# 1159    16172          Shahfahad      BS(SE)    CSD-FALL-19
# 1160    16172          Shahfahad      BS(SE)    CSD-FALL-19
# 1161    16172          Shahfahad      BS(SE)    CSD-FALL-19
# 1162    16172          Shahfahad      BS(SE)    CSD-FALL-19
# 1163    16172          Shahfahad      BS(SE)    CSD-FALL-19
#
#                                         NAME2  CRHRS  MARKS  POINTS  \
# 0                  HUMAN COMPUTER INTERACTION      3   74.0     3.0
# 1        INFORMATION SYSTEM & DATA PROCESSING      3   84.0     3.5
# ...

# %%
# df_agr = df.groupby(['ALTCODE','NAME2'])
df_agr.head()
# Out:
#       ALTCODE               NAME DEGREE_CODE       SEM_CODE  \
# 0       16550  Muhammad Ali Khan      BS(SE)  CSD-SPRING-20
# 1       16550  Muhammad Ali Khan      BS(SE)  CSD-SPRING-20
# 2       16550  Muhammad Ali Khan      BS(SE)  CSD-SPRING-20
# 3       16550  Muhammad Ali Khan      BS(SE)  CSD-SPRING-20
# 4       16550  Muhammad Ali Khan      BS(SE)  CSD-SPRING-20
# ...       ...                ...         ...            ...
# 2268    16417         Rooh Ullah      BS(SE)  CSD-SPRING-21
# 2269    16417         Rooh Ullah      BS(SE)  CSD-SPRING-21
# 2270    16417         Rooh Ullah      BS(SE)  CSD-SPRING-21
# 2271    16417         Rooh Ullah      BS(SE)  CSD-SPRING-21
# 2272    16417         Rooh Ullah      BS(SE)  CSD-SPRING-21
#
#                                         NAME2  CRHRS  MARKS  POINTS  \
# 0                  HUMAN COMPUTER INTERACTION      3   74.0     3.0
# 1        INFORMATION SYSTEM & DATA PROCESSING      3   84.0     3.5
# ...

# %%
group = df[['ALTCODE', 'NAME2','MARKS']].groupby('MARKS').max()
group.head()
# Out:
#        ALTCODE                                  NAME2
# MARKS
# 0.0      16737      PROGRAMMING FUNDAMENTALS (THEORY)
# 2.0      16281       PROGRAMING FUNDAMENTALS (THEORY)
# 3.0      16425      PROGRAMMING FUNDAMENTALS (THEORY)
# 4.0      16737  ENGLISH COMPOSITION AND COMPREHENSION
# 5.0      15791       PROGRAMING FUNDAMENTALS (THEORY)
# ...        ...                                    ...
# 96.0     16607         PROGRAMMING FUNDAMENTALS (LAB)
# 97.0     16107         PROGRAMMING FUNDAMENTALS (LAB)
# 98.0     16550         PROGRAMMING FUNDAMENTALS (LAB)
# 99.0     16549             DATABASE  SYSYEMS (THEORY)
# 100.0    16051         PROGRAMMING FUNDAMENTALS (LAB)
#
# [98 rows x 2 columns]

# %%
# df[df.A > df.B]

# %%
# df.query('A > B')

# %%
# df.query('B == `C C`')

# %%
# df.add(1)

# %%
# df.div(10)

# %%
# df.groupby(['Animal']).min()
